# %%
import pandas as pd
import xlrd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\김진태'

# %%
excel_file = "C:\\Temp\\NsmData\data20190417.xlsx"
if not os.path.exists(excel_file): 
    print(excel_file + ' file not found!! ')

# %%
df = pd.read_excel(excel_file, Sheet_name='Sheet1')

# %%
df.keys()
# Out:
# Index(['순번', '구분', '주담당채널', '주담당부서', '주담당자', '영업채널명', '영업부서명', '영업담당자명', '고객명',
#        '사업자/주민', '주문번호', '주문일자', '주문상태', '주문현황', '납입구분', '상품명', '단위상품명', '사용자',
#        '공급가', '금액(VAT별도)', '반품금액(VAT별도)', '수주잔액(VAT별도)', '전화번호', 'FAX', '비고',
#        '기타', '주소', '고객구분', '세무구분', '판매유형', '영업형태', '세무대리증빙', '약정기간', '구매증빙',
#        '프로모션명', '패키지 Pack 여부', '전자세금계산서발행여부', '관계사발행', '기회시작일', '경과일', '활동건수',
#        '영업유형', '매출국가', '정산분류', '영업실적율', '영업실적금액', '구분.1', '부서명', '사원명',
#        '영업실적율.1', '영업실적금액.1', '구분.2', '부서명.1', '사원명.1'],
#       dtype='object')

# %%
df1 = df[['주담당채널', '영업채널명', '영업담당자명', '고객명', '사업자/주민', '주문일자', '주문상태', '주문현황', '납입구분', '상품명', '단위상품명', '공급가', '금액(VAT별도)', '판매유형', '기회시작일' ]]

# %%
product_category = {'ICUBE 클라우드서버', 'Bizbox Alpha Cloud'}

# %%
'ICUBE 클라우드서버' in product_category
# Out:
# True

# %%
df1['상품명'].apply(lambda x : x in product_category)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# Name: 상품명, dtype: bool

# %%
#df1['상품명']
df1['상품명'].isin(product_category)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# Name: 상품명, dtype: bool

# %%
df2 = df1[df1['상품명'].isin(product_category)]

# %%
df2
# Out:
#            주담당채널       영업채널명 영업담당자명          고객명        사업자/주민        주문일자  \
# 3   서울1,2 IT코디센터  서울1 IT코디센터    김민지      (주)지엔오션  403-87-00573  2019-04-17
# 4   서울1,2 IT코디센터  서울1 IT코디센터    김민지      (주)지엔오션  403-87-00573  2019-04-17
# 5   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 6   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 7   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 8   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 9   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 31      중부IT코디센터    중부IT코디센터    성민석      주식회사 웰텍  314-86-60600  2019-04-17
# 32      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# 33      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# 34      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# ...

# %%
groupby_columns_list = ['영업채널명', '영업담당자명', '사업자/주민', '고객명', '상품명', '판매유형', '기회시작일']

# %%
df2.groupby(groupby_columns_list).size().reset_index(name='count')
# Out:
#         영업채널명 영업담당자명        사업자/주민          고객명                 상품명 판매유형  \
# 0  서울1 IT코디센터    김민지  403-87-00573      (주)지엔오션  Bizbox Alpha Cloud   업셀
# 1  서울1 IT코디센터    송재웅  120-87-84760      주식회사 퀄슨        ICUBE 클라우드서버   신규
# 2      엠아이솔루션    전지원  133-81-19093    디와이엘라센(주)        ICUBE 클라우드서버   신규
# 3      유니에스아이    박준호  211-88-68802  유한회사 알지피코리아        ICUBE 클라우드서버   신규
# 4    중부IT코디센터    성민석  314-86-60600      주식회사 웰텍  Bizbox Alpha Cloud   추가
# 5    호남IT코디센터    김기성  411-82-11004  (재)녹색에너지연구원        ICUBE 클라우드서버   신규
#
#         기회시작일  count
# 0  2019-04-17      2
# 1  2019-04-17      5
# 2  2019-04-17      3
# 3  2019-04-17      4
# 4  2019-04-17      1
# 5  2019-04-17      4

# %%
grouped_df = df2.groupby(groupby_columns_list)

# %%
grouped_df.sum().reset_index()
# Out:
#         영업채널명 영업담당자명        사업자/주민          고객명                 상품명 판매유형  \
# 0  서울1 IT코디센터    김민지  403-87-00573      (주)지엔오션  Bizbox Alpha Cloud   업셀
# 1  서울1 IT코디센터    송재웅  120-87-84760      주식회사 퀄슨        ICUBE 클라우드서버   신규
# 2      엠아이솔루션    전지원  133-81-19093    디와이엘라센(주)        ICUBE 클라우드서버   신규
# 3      유니에스아이    박준호  211-88-68802  유한회사 알지피코리아        ICUBE 클라우드서버   신규
# 4    중부IT코디센터    성민석  314-86-60600      주식회사 웰텍  Bizbox Alpha Cloud   추가
# 5    호남IT코디센터    김기성  411-82-11004  (재)녹색에너지연구원        ICUBE 클라우드서버   신규
#
#         기회시작일       공급가  금액(VAT별도)
# 0  2019-04-17  12200000     100000
# 1  2019-04-17         0    3660000
# 2  2019-04-17         0    2640000
# 3  2019-04-17         0    5469600
# 4  2019-04-17     20000      12000
# 5  2019-04-17         0    3300000

# %%
pd.DataFrame(grouped_df.size().reset_index(name = "Group_Count"))
# Out:
#         영업채널명 영업담당자명        사업자/주민          고객명                 상품명 판매유형  \
# 0  서울1 IT코디센터    김민지  403-87-00573      (주)지엔오션  Bizbox Alpha Cloud   업셀
# 1  서울1 IT코디센터    송재웅  120-87-84760      주식회사 퀄슨        ICUBE 클라우드서버   신규
# 2      엠아이솔루션    전지원  133-81-19093    디와이엘라센(주)        ICUBE 클라우드서버   신규
# 3      유니에스아이    박준호  211-88-68802  유한회사 알지피코리아        ICUBE 클라우드서버   신규
# 4    중부IT코디센터    성민석  314-86-60600      주식회사 웰텍  Bizbox Alpha Cloud   추가
# 5    호남IT코디센터    김기성  411-82-11004  (재)녹색에너지연구원        ICUBE 클라우드서버   신규
#
#         기회시작일  Group_Count
# 0  2019-04-17            2
# 1  2019-04-17            5
# 2  2019-04-17            3
# 3  2019-04-17            4
# 4  2019-04-17            1
# 5  2019-04-17            4

# %%
pd.DataFrame(grouped_df['금액(VAT별도)'].sum().reset_index(name='총금액'))
# Out:
#         영업채널명 영업담당자명        사업자/주민          고객명                 상품명 판매유형  \
# 0  서울1 IT코디센터    김민지  403-87-00573      (주)지엔오션  Bizbox Alpha Cloud   업셀
# 1  서울1 IT코디센터    송재웅  120-87-84760      주식회사 퀄슨        ICUBE 클라우드서버   신규
# 2      엠아이솔루션    전지원  133-81-19093    디와이엘라센(주)        ICUBE 클라우드서버   신규
# 3      유니에스아이    박준호  211-88-68802  유한회사 알지피코리아        ICUBE 클라우드서버   신규
# 4    중부IT코디센터    성민석  314-86-60600      주식회사 웰텍  Bizbox Alpha Cloud   추가
# 5    호남IT코디센터    김기성  411-82-11004  (재)녹색에너지연구원        ICUBE 클라우드서버   신규
#
#         기회시작일      총금액
# 0  2019-04-17   100000
# 1  2019-04-17  3660000
# 2  2019-04-17  2640000
# 3  2019-04-17  5469600
# 4  2019-04-17    12000
# 5  2019-04-17  3300000

# %%
df2.groupby(['고객명', '상품명'], as_index=True)['금액(VAT별도)'].sum()
# Out:
# 고객명          상품명
# (재)녹색에너지연구원  ICUBE 클라우드서버          3300000
# (주)지엔오션      Bizbox Alpha Cloud     100000
# 디와이엘라센(주)    ICUBE 클라우드서버          2640000
# 유한회사 알지피코리아  ICUBE 클라우드서버          5469600
# 주식회사 웰텍      Bizbox Alpha Cloud      12000
# 주식회사 퀄슨      ICUBE 클라우드서버          3660000
# Name: 금액(VAT별도), dtype: int64

# %%
df2.groupby(groupby_columns_list, as_index=False)['금액(VAT별도)'].sum()
# Out:
#         영업채널명 영업담당자명        사업자/주민          고객명                 상품명 판매유형  \
# 0  서울1 IT코디센터    김민지  403-87-00573      (주)지엔오션  Bizbox Alpha Cloud   업셀
# 1  서울1 IT코디센터    송재웅  120-87-84760      주식회사 퀄슨        ICUBE 클라우드서버   신규
# 2      엠아이솔루션    전지원  133-81-19093    디와이엘라센(주)        ICUBE 클라우드서버   신규
# 3      유니에스아이    박준호  211-88-68802  유한회사 알지피코리아        ICUBE 클라우드서버   신규
# 4    중부IT코디센터    성민석  314-86-60600      주식회사 웰텍  Bizbox Alpha Cloud   추가
# 5    호남IT코디센터    김기성  411-82-11004  (재)녹색에너지연구원        ICUBE 클라우드서버   신규
#
#         기회시작일  금액(VAT별도)
# 0  2019-04-17     100000
# 1  2019-04-17    3660000
# 2  2019-04-17    2640000
# 3  2019-04-17    5469600
# 4  2019-04-17      12000
# 5  2019-04-17    3300000

# %%
dfg = df2.groupby(['고객명', '상품명'], as_index=False)

# %%
sum_df = dfg['금액(VAT별도)'].sum()

# %%
df2.apply(lambda row: row)
# Out:
#            주담당채널       영업채널명 영업담당자명          고객명        사업자/주민        주문일자  \
# 3   서울1,2 IT코디센터  서울1 IT코디센터    김민지      (주)지엔오션  403-87-00573  2019-04-17
# 4   서울1,2 IT코디센터  서울1 IT코디센터    김민지      (주)지엔오션  403-87-00573  2019-04-17
# 5   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 6   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 7   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 8   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 9   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 31      중부IT코디센터    중부IT코디센터    성민석      주식회사 웰텍  314-86-60600  2019-04-17
# 32      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# 33      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# 34      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# ...

# %%
for name, group in grouped_df:
    ix = grouped_df.indices[name]
    #print(type(group))
    #print(group.loc[:,'영업담당자명'])
    #print(group)
    print("index {0} : {1}".format(ix, name))
    print("-"*20)
    for cname in group:
        print("{0} : {1}".format(cname, group[cname]))
# Out:
# index [ 8  9 10 11] : ('(재)녹색에너지연구원', 'ICUBE 클라우드서버')
# --------------------
# 주담당채널 : 32    호남IT코디센터
# 33    호남IT코디센터
# 34    호남IT코디센터
# 35    호남IT코디센터
# Name: 주담당채널, dtype: object
# 영업채널명 : 32    호남IT코디센터
# 33    호남IT코디센터
# 34    호남IT코디센터
# 35    호남IT코디센터
# Name: 영업채널명, dtype: object
# 영업담당자명 : 32    김기성
# 33    김기성
# 34    김기성
# 35    김기성
# Name: 영업담당자명, dtype: object
# 고객명 : 32    (재)녹색에너지연구원
# 33    (재)녹색에너지연구원
# 34    (재)녹색에너지연구원
# 35    (재)녹색에너지연구원
# Name: 고객명, dtype: object
# 사업자/주민 : 32    411-82-11004
# 33    411-82-11004
# 34    411-82-11004
# 35    411-82-11004
# Name: 사업자/주민, dtype: object
# 주문일자 : 32    2019-04-17
# 33    2019-04-17
# 34    2019-04-17
# 35    2019-04-17
# Name: 주문일자, dtype: object
# 주문상태 : 32    주문완료
# 33    주문완료
# 34    주문완료
# 35    주문완료
# Name: 주문상태, dtype: object
# 주문현황 : 32    발송중
# 33    발송중
# 34    발송중
# 35    발송중
# Name: 주문현황, dtype: object
# 납입구분 : 32    일시납
# 33    일시납
# 34    일시납
# 35    일시납
# Name: 납입구분, dtype: object
# ...

# %%
s1 = df2.iloc[15]

# %%
df2
# Out:
#            주담당채널       영업채널명 영업담당자명          고객명        사업자/주민        주문일자  \
# 3   서울1,2 IT코디센터  서울1 IT코디센터    김민지      (주)지엔오션  403-87-00573  2019-04-17
# 4   서울1,2 IT코디센터  서울1 IT코디센터    김민지      (주)지엔오션  403-87-00573  2019-04-17
# 5   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 6   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 7   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 8   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 9   서울1,2 IT코디센터  서울1 IT코디센터    송재웅      주식회사 퀄슨  120-87-84760  2019-04-17
# 31      중부IT코디센터    중부IT코디센터    성민석      주식회사 웰텍  314-86-60600  2019-04-17
# 32      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# 33      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# 34      호남IT코디센터    호남IT코디센터    김기성  (재)녹색에너지연구원  411-82-11004  2019-04-17
# ...

# %%
s1
# Out:
# 주담당채널                 NaN
# 영업채널명              유니에스아이
# 영업담당자명                박준호
# 고객명           유한회사 알지피코리아
# 사업자/주민       211-88-68802
# 주문일자           2019-04-17
# 주문상태                 주문완료
# 주문현황                 주문완료
# 납입구분                  일시납
# 상품명          ICUBE 클라우드서버
# 단위상품명          클라우드서버(기본)
# 공급가                     0
# 금액(VAT별도)         3369600
# 판매유형                   신규
# 기회시작일          2019-04-17
# Name: 46, dtype: object
